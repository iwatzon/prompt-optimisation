# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

model = "gpt-3.5-turbo"

if model == "gpt-3.5-turbo":
    model_in_title = "GPT-3.5-Turbo"
    # Data for GSM8K
    data_gsm8k = {
        'Prompt': ['Baseline', 'ZS-CoT', 'Emotive', 'Authoritarian_GPT4o', 'Market_GPT4o', 'Hierarchical_GPT4o', 'Authoritarian_Claude', 'Market_Claude', 'Hierarchical_Claude'],
        'Mean': [0.856, 0.633, 0.744, 0.689, 0.733, 0.800, 0.733, 0.511, 0.456],
        'Median': [0.867, 0.633, 0.767, 0.833, 0.800, 0.767, 0.767, 0.733, 0.500],
        'Max': [0.900, 0.667, 0.767, 0.867, 0.800, 0.900, 0.767, 0.800, 0.767],
        'Std Dev': [0.041, 0.027, 0.032, 0.228, 0.094, 0.072, 0.047, 0.362, 0.274]
    }
    gsm8k_baseline_mean = 0.856

    # Data for SST-2
    data_sst2 = {
        'Prompt': ['Baseline', 'ZS-CoT', 'Emotive', 'Authoritarian_GPT4o', 'Market_GPT4o', 'Hierarchical_GPT4o', 'Authoritarian_Claude', 'Market_Claude', 'Hierarchical_Claude'],
        'Mean': [0.967, 0.622, 0.967, 0.933, 0.933, 0.944, 0.967, 0.811, 0.933],
        'Median': [0.967, 0.633, 0.967, 0.933, 0.933, 0.933, 0.967, 0.800, 0.933],
        'Max': [0.967, 0.633, 0.967, 0.967, 0.967, 0.967, 0.967, 0.867, 0.967],
        'Std Dev': [0.000, 0.016, 0.000, 0.027, 0.027, 0.016, 0.000, 0.042, 0.027]
    }
    sst2_baseline_mean = 0.967

    # Data for HumanEval
    data_humaneval = {
        'Prompt': ['Baseline', 'ZS-CoT', 'Emotive', 'Authoritarian_GPT4o', 'Market_GPT4o', 'Hierarchical_GPT4o', 'Authoritarian_Claude', 'Market_Claude', 'Hierarchical_Claude'],
        'Mean': [0.800, 0.867, 0.767, 0.811, 0.745, 0.744, 0.722, 0.778, 0.822],
        'Median': [0.800, 0.867, 0.767, 0.800, 0.767, 0.767, 0.833, 0.767, 0.833],
        'Max': [0.800, 0.867, 0.767, 0.833, 0.767, 0.833, 0.867, 0.800, 0.833],
        'Std Dev': [0.000, 0.000, 0.000, 0.016, 0.032, 0.083, 0.181, 0.016, 0.016]
    }
    humaneval_baseline_mean = 0.800

if model == "mistralv0.3":
    model_in_title = "Mistral-V0.3-7B"
    # Data for GSM8K
    data_gsm8k = {
        'Prompt': ['Baseline', 'CoT', 'Emotive', 'Authoritarian_GPT4o', 'Market_GPT4o', 'Hierarchical_GPT4o', 'Authoritarian_Claude', 'Market_Claude', 'Hierarchical_Claude'],
        'Mean': [0.200, 0.267, 0.067, 0.144, 0.433, 0.367, 0.278, 0.233, 0.067],
        'Median': [0.200, 0.267, 0.067, 0.033, 0.433, 0.400, 0.300, 0.233, 0.000],
        'Max': [0.200, 0.267, 0.067, 0.400, 0.533, 0.467, 0.533, 0.467, 0.200],
        'Std Dev': [0.000, 0.000, 0.000, 0.181, 0.082, 0.098, 0.218, 0.191, 0.094]
    }
    gsm8k_baseline_mean = 0.200

    # Data for SST-2
    data_sst2 = {
        'Prompt': ['Baseline', 'CoT', 'Emotive', 'Authoritarian_GPT4o', 'Market_GPT4o', 'Hierarchical_GPT4o', 'Authoritarian_Claude', 'Market_Claude', 'Hierarchical_Claude'],
        'Mean': [0.667, 0.700, 0.711, 0.867, 0.711, 0.811, 0.489, 0.433, 0.700],
        'Median': [0.667, 0.700, 0.700, 0.867, 0.733, 0.833, 0.533, 0.600, 0.667],
        'Max': [0.667, 0.700, 0.733, 0.900, 0.833, 0.933, 0.800, 0.667, 0.800],
        'Std Dev': [0.000, 0.000, 0.000, 0.027, 0.110, 0.110, 0.274, 0.284, 0.072]
    }
    sst2_baseline_mean = 0.667

    # Data for HumanEval
    data_humaneval = {
        'Prompt': ['Baseline', 'CoT', 'Emotive', 'Authoritarian_GPT4o', 'Market_GPT4o', 'Hierarchical_GPT4o', 'Authoritarian_Claude', 'Market_Claude', 'Hierarchical_Claude'],
        'Mean': [0.467, 0.433, 0.467, 0.455, 0.356, 0.389, 0.255, 0.389, 0.422],
        'Median': [0.467, 0.433, 0.467, 0.500, 0.400, 0.367, 0.233, 0.400, 0.467],
        'Max': [0.467, 0.433, 0.467, 0.533, 0.467, 0.467, 0.400, 0.467, 0.467],
        'Std Dev': [0.000, 0.000, 0.000, 0.088, 0.113, 0.057, 0.110, 0.069, 0.063]
    }
    humaneval_baseline_mean = 0.467

if model == "llama3.1":
    model_in_title = "Llama-3.1-8B"
    data_gsm8k = {
        'Prompt': ['Baseline', 'CoT', 'Emotive', 'Authoritarian_GPT4o', 'Market_GPT4o', 'Hierarchical_GPT4o', 'Authoritarian_Claude', 'Market_Claude', 'Hierarchical_Claude'],
        'Mean': [0.033, 0.100, 0.067, 0.333, 0.200, 0.044, 0.278, 0.100, 0.100],
        'Median': [0.033, 0.100, 0.067, 0.300, 0.133, 0.067, 0.267, 0.133, 0.033],
        'Max': [0.033, 0.100, 0.067, 0.667, 0.433, 0.067, 0.567, 0.167, 0.267],
        'Std Dev': [0.000, 0.000, 0.000, 0.260, 0.170, 0.057, 0.231, 0.072, 0.119]
    }
    gsm8k_baseline_mean = 0.033   

    data_sst2 = {     
            'Prompt': ['Baseline', 'CoT', 'Emotive', 'Authoritarian_GPT4o', 'Market_GPT4o', 'Hierarchical_GPT4o', 'Authoritarian_Claude', 'Market_Claude', 'Hierarchical_Claude'],
        'Mean': [0.800, 0.811, 0.800, 0.889, 0.856, 0.933, 0.800, 0.322, 0.867],
        'Median': [0.800, 0.800, 0.800, 0.900, 0.800, 0.967, 0.867, 0.233, 0.900],
        'Max': [0.800, 0.833, 0.800, 0.967, 0.967, 0.967, 0.967, 0.667, 0.900],
        'Std Dev': [0.000, 0.000, 0.000, 0.068, 0.079, 0.047, 0.170, 0.253, 0.047]
    }
    sst2_baseline_mean = 0.800

    data_humaneval = {
        'Prompt': ['Baseline', 'CoT', 'Emotive', 'Authoritarian_GPT4o', 'Market_GPT4o', 'Hierarchical_GPT4o', 'Authoritarian_Claude', 'Market_Claude', 'Hierarchical_Claude'],
        'Mean': [0.600, 0.667, 0.667, 0.333, 0.622, 0.578, 0.345, 0.611, 0.556],
        'Median': [0.600, 0.667, 0.667, 0.233, 0.667, 0.567, 0.400, 0.600, 0.600],
        'Max': [0.600, 0.667, 0.667, 0.600, 0.700, 0.733, 0.467, 0.667, 0.600],
        'Std Dev': [0.000, 0.000, 0.000, 0.190, 0.087, 0.123, 0.129, 0.041, 0.063]
    }
    humaneval_baseline_mean = 0.600

# Convert to DataFrames
df_gsm8k = pd.DataFrame(data_gsm8k)
df_sst2 = pd.DataFrame(data_sst2)
df_humaneval = pd.DataFrame(data_humaneval)

# Calculate differences from baseline
df_gsm8k_diff = df_gsm8k.copy()
df_gsm8k_diff.iloc[:, 1:4] = df_gsm8k_diff.iloc[:, 1:4].subtract(gsm8k_baseline_mean)

df_sst2_diff = df_sst2.copy()
df_sst2_diff.iloc[:, 1:4] = df_sst2_diff.iloc[:, 1:4].subtract(sst2_baseline_mean)

df_humaneval_diff = df_humaneval.copy()
df_humaneval_diff.iloc[:, 1:4] = df_humaneval_diff.iloc[:, 1:4].subtract(humaneval_baseline_mean)

# Melt DataFrames for easier plotting
df_gsm8k_melted = df_gsm8k_diff.melt(id_vars=['Prompt', 'Std Dev'], var_name='Metric', value_name='Score')
df_sst2_melted = df_sst2_diff.melt(id_vars=['Prompt', 'Std Dev'], var_name='Metric', value_name='Score')
df_humaneval_melted = df_humaneval_diff.melt(id_vars=['Prompt', 'Std Dev'], var_name='Metric', value_name='Score')

# Set the style and context to mimic LaTeX
sns.set(style="white", context="paper", palette="deep", font_scale=1.5)

# Update rcParams for a LaTeX-like font
plt.rcParams.update({
    "mathtext.fontset": "dejavuserif",
    "font.family": "serif",
    "font.serif": ["DejaVu Serif"],
    "axes.unicode_minus": False
})

# Create plots
def create_plot(df, title, filename):
    plt.figure(figsize=(12, 6))
    # Filter only the 'Mean' metric for bar plot
    df_mean = df[df['Metric'] == 'Mean']
    colors = ['green' if score > 0 else 'red' for score in df_mean['Score']]
    bars = sns.barplot(data=df_mean, x='Prompt', y='Score', edgecolor='black', linewidth=1.5, palette=colors)
    
    # Plot the max values as dots
    df_max = df[df['Metric'] == 'Max']
    for i, (prompt, score) in enumerate(zip(df_max['Prompt'], df_max['Score'])):
        plt.plot(i, score, 'ko', markersize=8, label='Max Score' if i == 0 else "")
    
    # Plot error bars for standard deviation
    for i, (mean, std) in enumerate(zip(df_mean['Score'], df_mean['Std Dev'])):
        plt.errorbar(i, mean, yerr=std, fmt='none', ecolor='black', capsize=5, capthick=1.5)

    plt.xticks(rotation=45, ha='right')
    plt.title(rf'{title}', fontsize=16, weight='bold')
    plt.xlabel(r'Prompt', fontsize=14)
    plt.ylabel(r'Difference from Baseline Mean (%)', fontsize=14)
    plt.axhline(0, color='grey', linestyle='--', linewidth=1.5)
    plt.legend(loc='lower right', fontsize=12)
    plt.tight_layout()
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    plt.show()

create_plot(df_gsm8k_melted, f'GSM8K Results - {model_in_title}', f'{model}/gsm8k_results.png')
create_plot(df_sst2_melted, f'SST-2 Results - {model_in_title}', f'{model}/sst2_results.png')
create_plot(df_humaneval_melted, f'HumanEval Results - {model_in_title}', f'{model}/humaneval_results.png')
# Out:
# /var/folders/gw/d7yf9y2s11v5m5yljzn3cgc40000gp/T/ipykernel_2653/362878081.py:137: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bars = sns.barplot(data=df_mean, x='Prompt', y='Score', edgecolor='black', linewidth=1.5, palette=colors)
# /var/folders/gw/d7yf9y2s11v5m5yljzn3cgc40000gp/T/ipykernel_2653/362878081.py:137: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bars = sns.barplot(data=df_mean, x='Prompt', y='Score', edgecolor='black', linewidth=1.5, palette=colors)
# /var/folders/gw/d7yf9y2s11v5m5yljzn3cgc40000gp/T/ipykernel_2653/362878081.py:137: FutureWarning:
#
# ...
